# %%
import torch.nn as nn
import torch
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from torch.utils.data import TensorDataset, DataLoader
from multiprocessing import cpu_count
from torch.nn import functional as F

# %%
if torch.cuda.is_available():
    device = 'cuda:0'
else:
    device = 'cpu'
pass

# %%
df = pd.read_csv(r'C:\Users\neele\OneDrive\Documents\Dataset\series\training\x_train.csv')

# %%
dfy = pd.read_csv(r'C:\Users\neele\OneDrive\Documents\Dataset\series\training\y_train.csv')

# %%
df.head()
# Out:
#   row_id  series_id  measurement_number  orientation_X  orientation_Y  \
# 0    0_0          0                   0       -0.75853       -0.63435
# 1    0_1          0                   1       -0.75853       -0.63434
# 2    0_2          0                   2       -0.75853       -0.63435
# 3    0_3          0                   3       -0.75852       -0.63436
# 4    0_4          0                   4       -0.75852       -0.63435
#
#    orientation_Z  orientation_W  angular_velocity_X  angular_velocity_Y  \
# 0       -0.10488       -0.10597            0.107650            0.017561
# 1       -0.10490       -0.10600            0.067851            0.029939
# 2       -0.10492       -0.10597            0.007275            0.028934
# 3       -0.10495       -0.10597           -0.013053            0.019448
# 4       -0.10495       -0.10596            0.005135            0.007652
#
#    angular_velocity_Z  linear_acceleration_X  linear_acceleration_Y  \
# 0            0.000767               -0.74857                 2.1030
# 1            0.003385                0.33995                 1.5064
# 2           -0.005978               -0.26429                 1.5922
# 3           -0.008974                0.42684                 1.0993
# 4            0.005245               -0.50969                 1.4689
#
#    linear_acceleration_Z
# 0                -9.7532
# 1                -9.4128
# 2                -8.7267
# 3               -10.0960
# 4               -10.4410

# %%
dfy.head()
# Out:
#    series_id  group_id        surface
# 0          0        13  fine_concrete
# 1          1        31       concrete
# 2          2        20       concrete
# 3          3        31       concrete
# 4          4        22     soft_tiles

# %%
enc = LabelEncoder()
y_enc = enc.fit_transform(dfy['surface'])
y_enc
# Out:
# array([2, 1, 1, ..., 2, 7, 5])

# %%
dfy['encoding'] = y_enc

# %%
df_grouped = df.groupby('series_id')

data = []

columns = ['orientation_X', 'orientation_Y', 'orientation_Z', 'orientation_W', 'angular_velocity_X',
       'angular_velocity_Y', 'angular_velocity_Z', 'linear_acceleration_X',
       'linear_acceleration_Y', 'linear_acceleration_Z']

for i, item in enumerate(df_grouped):
    
    group_data = []
    # print(item[1])

    for row in item[1].iterrows():

        row_data = []
        
        for column in columns:
            
            row_data.append(row[1][column])

        group_data.append(row_data)

    data.append((group_data,y_enc[i]))

# %%
data_df = pd.DataFrame(data, columns=['X','y'])

# %%
X = list(data_df['X'])

# %%
y = list(data_df['y'])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1, random_state=42)

# %%
len(X_train)
# Out:
# 3429

# %%
x_train = torch.FloatTensor(X_train).to(device)
y_train = torch.LongTensor(y_train).to(device)

x_test = torch.FloatTensor(X_test).to(device)
y_test = torch.LongTensor(y_test).to(device)

# %%
train_ds = TensorDataset(x_train, y_train)
valid_ds = TensorDataset(x_test, y_test)

train_loader = DataLoader(train_ds, 128, shuffle=True)
test_loader = DataLoader(valid_ds, 128, shuffle=False)

# %%
class LSTMModule(nn.Module):

    def __init__(self):
        super(LSTMModule, self).__init__()

        self.input_layer_size = 10
        self.hidden_layer_size = 256
        self.output_layer_size = 9

        self.lstm = nn.LSTM(self.input_layer_size, self.hidden_layer_size, 3, batch_first=True)
        self.fc = nn.Linear(self.hidden_layer_size, self.output_layer_size)

    def forward(self, input_seq):

        self.hidden_cell = (torch.zeros(3,input_seq.size(0),self.hidden_layer_size).to(device), torch.zeros(3,input_seq.size(0),self.hidden_layer_size).to(device))

        lstm_out, self.hidden_cell = self.lstm(input_seq, self.hidden_cell)
        predictions = self.fc(lstm_out[:, -1, :])
        return predictions

# %%
model = LSTMModule().to(device)

criterion = nn.CrossEntropyLoss().to(device)
optimizer = torch.optim.RMSprop(model.parameters(), lr=0.0005)

# %%
epochs = 500

running_loss_history = []
epoch_list = []
running_corrects_history = []
val_running_loss_history = []
val_running_corrects_history = []

for epoch in range(epochs):

    running_corrects = 0.0
    val_running_loss = 0.0
    val_running_corrects = 0.0

    running_loss = 0.0

    model.train()

    for inputs, labels in train_loader:

        inputs = inputs.to(device)
        labels = labels.to(device)

        output = model(inputs)

        loss = criterion(output, labels)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        preds = F.log_softmax(output, dim=1).argmax(dim=1)
        running_loss += loss.item()
        running_corrects += (preds == labels).sum().item()

    else:
        correct, total = 0, 0
        model.eval()
        
        with torch.no_grad():

            for val_inputs, val_labels in test_loader:

                val_inputs = val_inputs.to(device)
                val_labels = val_labels.to(device)

                val_outputs = model(val_inputs)
                val_loss = criterion(val_outputs, val_labels)

                val_preds = F.log_softmax(val_outputs, dim=1).argmax(dim=1)

                total += val_labels.size(0)

                val_running_loss += val_loss.item()
                val_running_corrects += (val_preds  == val_labels).sum().item()

    
    if epoch % 5 == 0:

        epoch_loss = running_loss/len(train_loader.dataset)
        epoch_acc = running_corrects / len(train_loader.dataset)
        running_loss_history.append(epoch_loss)
        running_corrects_history.append(epoch_acc)
        
        val_epoch_loss = val_running_loss/len(test_loader.dataset)
        val_epoch_acc = val_running_corrects / len(test_loader.dataset)
        val_running_loss_history.append(val_epoch_loss)
        val_running_corrects_history.append(val_epoch_acc)
        print('epoch :', (epoch+1))
        print('training loss: {:.4f}, acc {:.4f} '.format(epoch_loss, epoch_acc))
        print('validation loss: {:.4f}, validation acc {:.4f} '.format(val_epoch_loss, val_epoch_acc))

        epoch_list.append(epoch + 1)

        print('_'*20)
# Out:
# epoch : 1
# training loss: 0.0160, acc 0.2114
# validation loss: 0.0157, validation acc 0.2520
# ____________________
# epoch : 6
# training loss: 0.0126, acc 0.4059
# validation loss: 0.0123, validation acc 0.4514
# ____________________
# epoch : 11
# training loss: 0.0109, acc 0.4853
# validation loss: 0.0106, validation acc 0.5381
# ____________________
# epoch : 16
# training loss: 0.0109, acc 0.4765
# validation loss: 0.0104, validation acc 0.5381
# ____________________
# epoch : 21
# training loss: 0.0093, acc 0.5687
# validation loss: 0.0089, validation acc 0.6063
# ____________________
# epoch : 26
# training loss: 0.0093, acc 0.5684
# validation loss: 0.0083, validation acc 0.6404
# ____________________
# epoch : 31
# training loss: 0.0094, acc 0.5698
# validation loss: 0.0082, validation acc 0.6194
# ____________________
# epoch : 36
# training loss: 0.0076, acc 0.6591
# validation loss: 0.0074, validation acc 0.6824
# ____________________
# epoch : 41
# training loss: 0.0072, acc 0.6760
# validation loss: 0.0093, validation acc 0.5433
# ____________________
# epoch : 46
# training loss: 0.0074, acc 0.6801
# validation loss: 0.0068, validation acc 0.6798
# ____________________
# epoch : 51
# training loss: 0.0059, acc 0.7334
# validation loss: 0.0061, validation acc 0.6850
# ____________________
# epoch : 56
# training loss: 0.0057, acc 0.7457
# validation loss: 0.0063, validation acc 0.6982
# ____________________
# epoch : 61
# training loss: 0.0048, acc 0.7827
# validation loss: 0.0060, validation acc 0.7323
# ____________________
# epoch : 66
# training loss: 0.0046, acc 0.7909
# validation loss: 0.0057, validation acc 0.7323
# ____________________
# epoch : 71
# training loss: 0.0047, acc 0.7877
# validation loss: 0.0058, validation acc 0.7375
# ____________________
# epoch : 76
# training loss: 0.0035, acc 0.8437
# validation loss: 0.0055, validation acc 0.7428
# ____________________
# epoch : 81
# training loss: 0.0040, acc 0.8253
# validation loss: 0.0064, validation acc 0.6929
# ____________________
# epoch : 86
# training loss: 0.0039, acc 0.8262
# validation loss: 0.0056, validation acc 0.7559
# ____________________
# epoch : 91
# training loss: 0.0042, acc 0.8276
# validation loss: 0.0083, validation acc 0.6719
# ____________________
# epoch : 96
# training loss: 0.0037, acc 0.8519
# validation loss: 0.0055, validation acc 0.7769
# ____________________
# epoch : 101
# training loss: 0.0028, acc 0.8787
# validation loss: 0.0060, validation acc 0.7927
# ____________________
# epoch : 106
# training loss: 0.0034, acc 0.8594
# validation loss: 0.0057, validation acc 0.7717
# ____________________
# epoch : 111
# training loss: 0.0018, acc 0.9306
# validation loss: 0.0068, validation acc 0.7218
# ____________________
# epoch : 116
# training loss: 0.0011, acc 0.9577
# validation loss: 0.0057, validation acc 0.7927
# ____________________
# epoch : 121
# training loss: 0.0010, acc 0.9609
# validation loss: 0.0055, validation acc 0.8031
# ____________________
# epoch : 126
# training loss: 0.0012, acc 0.9592
# validation loss: 0.0063, validation acc 0.7638
# ____________________
# epoch : 131
# training loss: 0.0024, acc 0.9099
# validation loss: 0.0058, validation acc 0.8084
# ____________________
# epoch : 136
# training loss: 0.0006, acc 0.9816
# validation loss: 0.0056, validation acc 0.8241
# ____________________
# epoch : 141
# training loss: 0.0019, acc 0.9218
# validation loss: 0.0066, validation acc 0.7717
# ____________________
# epoch : 146
# training loss: 0.0008, acc 0.9705
# validation loss: 0.0068, validation acc 0.7585
# ____________________
# epoch : 151
# training loss: 0.0004, acc 0.9875
# validation loss: 0.0056, validation acc 0.8346
# ____________________
# epoch : 156
# training loss: 0.0008, acc 0.9749
# validation loss: 0.0059, validation acc 0.7953
# ____________________
# epoch : 161
# training loss: 0.0003, acc 0.9895
# validation loss: 0.0057, validation acc 0.8346
# ____________________
# epoch : 166
# training loss: 0.0006, acc 0.9784
# validation loss: 0.0060, validation acc 0.8031
# ____________________
# epoch : 171
# training loss: 0.0005, acc 0.9837
# validation loss: 0.0074, validation acc 0.8058
# ____________________
# epoch : 176
# training loss: 0.0005, acc 0.9813
# validation loss: 0.0062, validation acc 0.7848
# ____________________
# epoch : 181
# training loss: 0.0010, acc 0.9624
# validation loss: 0.0061, validation acc 0.7979
# ____________________
# epoch : 186
# training loss: 0.0019, acc 0.9379
# validation loss: 0.0073, validation acc 0.7769
# ____________________
# epoch : 191
# training loss: 0.0002, acc 0.9953
# validation loss: 0.0074, validation acc 0.7717
# ____________________
# epoch : 196
# training loss: 0.0003, acc 0.9898
# validation loss: 0.0063, validation acc 0.7979
# ____________________
# epoch : 201
# training loss: 0.0007, acc 0.9740
# validation loss: 0.0067, validation acc 0.7874
# ____________________
# epoch : 206
# training loss: 0.0006, acc 0.9784
# validation loss: 0.0074, validation acc 0.8005
# ____________________
# epoch : 211
# training loss: 0.0010, acc 0.9557
# validation loss: 0.0062, validation acc 0.7953
# ____________________
# epoch : 216
# training loss: 0.0001, acc 0.9980
# validation loss: 0.0063, validation acc 0.8110
# ____________________
# epoch : 221
# training loss: 0.0007, acc 0.9781
# validation loss: 0.0067, validation acc 0.8005
# ____________________
# epoch : 226
# training loss: 0.0003, acc 0.9889
# validation loss: 0.0085, validation acc 0.7717
# ____________________
# epoch : 231
# training loss: 0.0002, acc 0.9930
# validation loss: 0.0067, validation acc 0.7953
# ____________________
# epoch : 236
# training loss: 0.0016, acc 0.9414
# validation loss: 0.0076, validation acc 0.7690
# ____________________
# epoch : 241
# training loss: 0.0001, acc 0.9980
# validation loss: 0.0070, validation acc 0.8136
# ____________________
# epoch : 246
# training loss: 0.0002, acc 0.9948
# validation loss: 0.0071, validation acc 0.8031
# ____________________
# epoch : 251
# training loss: 0.0019, acc 0.9358
# validation loss: 0.0072, validation acc 0.7743
# ____________________
# epoch : 256
# training loss: 0.0001, acc 0.9988
# validation loss: 0.0074, validation acc 0.7953
# ____________________
# epoch : 261
# training loss: 0.0003, acc 0.9895
# validation loss: 0.0067, validation acc 0.8084
# ____________________
# epoch : 266
# training loss: 0.0002, acc 0.9921
# validation loss: 0.0067, validation acc 0.8058
# ____________________
# epoch : 271
# training loss: 0.0000, acc 0.9997
# validation loss: 0.0072, validation acc 0.8005
# ____________________
# epoch : 276
# training loss: 0.0000, acc 1.0000
# validation loss: 0.0066, validation acc 0.8136
# ____________________
# epoch : 281
# training loss: 0.0000, acc 0.9997
# validation loss: 0.0070, validation acc 0.8163
# ____________________
# epoch : 286
# training loss: 0.0001, acc 0.9977
# validation loss: 0.0063, validation acc 0.8058
# ____________________
# epoch : 291
# training loss: 0.0000, acc 0.9994
# validation loss: 0.0069, validation acc 0.8136
# ____________________
# epoch : 296
# training loss: 0.0000, acc 0.9997
# validation loss: 0.0074, validation acc 0.8241
# ____________________
# epoch : 301
# training loss: 0.0002, acc 0.9948
# validation loss: 0.0062, validation acc 0.7769
# ____________________
# epoch : 306
# training loss: 0.0000, acc 0.9997
# validation loss: 0.0071, validation acc 0.7900
# ____________________
# epoch : 311
# training loss: 0.0004, acc 0.9837
# validation loss: 0.0068, validation acc 0.8058
# ____________________
# epoch : 316
# training loss: 0.0000, acc 1.0000
# validation loss: 0.0071, validation acc 0.8136
# ____________________
# epoch : 321
# training loss: 0.0000, acc 1.0000
# validation loss: 0.0076, validation acc 0.8163
# ____________________
# epoch : 326
# training loss: 0.0000, acc 1.0000
# validation loss: 0.0081, validation acc 0.8163
# ____________________
# epoch : 331
# training loss: 0.0000, acc 1.0000
# validation loss: 0.0088, validation acc 0.8136
# ____________________
# epoch : 336
# training loss: 0.0000, acc 1.0000
# validation loss: 0.0094, validation acc 0.8110
# ____________________
# epoch : 341
# training loss: 0.0000, acc 1.0000
# validation loss: 0.0102, validation acc 0.8110
# ____________________
# epoch : 346
# training loss: 0.0000, acc 1.0000
# validation loss: 0.0108, validation acc 0.8163
# ____________________
# epoch : 351
# training loss: 0.0000, acc 1.0000
# validation loss: 0.0115, validation acc 0.8136
# ____________________
# epoch : 356
# training loss: 0.0000, acc 1.0000
# validation loss: 0.0122, validation acc 0.8110
# ____________________
# epoch : 361
# training loss: 0.0004, acc 0.9869
# validation loss: 0.0072, validation acc 0.7953
# ____________________
# epoch : 366
# training loss: 0.0000, acc 1.0000
# validation loss: 0.0074, validation acc 0.8136
# ____________________
# epoch : 371
# training loss: 0.0000, acc 1.0000
# validation loss: 0.0079, validation acc 0.8189
# ____________________
# epoch : 376
# training loss: 0.0031, acc 0.9183
# validation loss: 0.0087, validation acc 0.7165
# ____________________
# epoch : 381
# training loss: 0.0004, acc 0.9875
# validation loss: 0.0082, validation acc 0.7769
# ____________________
# epoch : 386
# training loss: 0.0000, acc 0.9997
# validation loss: 0.0079, validation acc 0.7953
# ____________________
# epoch : 391
# training loss: 0.0000, acc 1.0000
# validation loss: 0.0080, validation acc 0.8058
# ____________________
# epoch : 396
# training loss: 0.0000, acc 1.0000
# validation loss: 0.0083, validation acc 0.8136
# ____________________
# epoch : 401
# training loss: 0.0007, acc 0.9714
# validation loss: 0.0079, validation acc 0.7638
# ____________________
# epoch : 406
# training loss: 0.0001, acc 0.9988
# validation loss: 0.0080, validation acc 0.7900
# ____________________
# epoch : 411
# training loss: 0.0000, acc 0.9997
# validation loss: 0.0084, validation acc 0.7953
# ____________________
# epoch : 416
# training loss: 0.0005, acc 0.9808
# validation loss: 0.0072, validation acc 0.7979
# ____________________
# epoch : 421
# training loss: 0.0000, acc 0.9997
# validation loss: 0.0075, validation acc 0.8031
# ____________________
# epoch : 426
# training loss: 0.0000, acc 1.0000
# validation loss: 0.0078, validation acc 0.8136
# ____________________
# epoch : 431
# training loss: 0.0001, acc 0.9994
# validation loss: 0.0072, validation acc 0.7979
# ____________________
# epoch : 436
# training loss: 0.0000, acc 1.0000
# validation loss: 0.0076, validation acc 0.8084
# ____________________
# epoch : 441
# training loss: 0.0000, acc 1.0000
# validation loss: 0.0081, validation acc 0.8084
# ____________________
# epoch : 446
# training loss: 0.0000, acc 1.0000
# validation loss: 0.0085, validation acc 0.8136
# ____________________
# epoch : 451
# training loss: 0.0000, acc 1.0000
# validation loss: 0.0089, validation acc 0.8084
# ____________________
# epoch : 456
# training loss: 0.0000, acc 1.0000
# validation loss: 0.0093, validation acc 0.8136
# ____________________
# epoch : 461
# training loss: 0.0041, acc 0.8915
# validation loss: 0.0085, validation acc 0.7375
# ____________________
# epoch : 466
# training loss: 0.0000, acc 0.9997
# validation loss: 0.0073, validation acc 0.7927
# ____________________
# epoch : 471
# training loss: 0.0000, acc 1.0000
# validation loss: 0.0079, validation acc 0.8005
# ____________________
# epoch : 476
# training loss: 0.0000, acc 1.0000
# validation loss: 0.0085, validation acc 0.8031
# ____________________
# epoch : 481
# training loss: 0.0000, acc 1.0000
# validation loss: 0.0089, validation acc 0.8058
# ____________________
# epoch : 486
# training loss: 0.0000, acc 1.0000
# validation loss: 0.0095, validation acc 0.8110
# ____________________
# epoch : 491
# training loss: 0.0000, acc 1.0000
# validation loss: 0.0101, validation acc 0.8163
# ____________________
# epoch : 496
# training loss: 0.0000, acc 1.0000
# validation loss: 0.0106, validation acc 0.8189
# ____________________

# %%
torch.save(model.state_dict(), 'best_career_con.pth')

# %%
plt.plot(epoch_list,running_loss_history)
plt.xlabel("Epochs")
plt.ylabel("Training Accuracy")
plt.title("Accuracy vs Number of Epochs")
plt.show()

# %%
predictions=[]
labels = []

with torch.no_grad():
    model.eval()

    for val_inputs, val_labels in test_loader:

        val_inputs = val_inputs.to(device)
        val_labels = val_labels.to(device)

        val_outputs = model(val_inputs)
        val_loss = criterion(val_outputs, val_labels)

        val_preds = F.log_softmax(val_outputs, dim=1).argmax(dim=1)

        predictions += val_preds.cpu().tolist()
        labels += val_labels.cpu().tolist()

        
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(labels,predictions)
cm

plt.figure(figsize=(10,6))
sns.heatmap(cm,annot=True)
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
# Out:
# Text(69.0, 0.5, 'Predicted Values')

# %%
from sklearn.metrics import accuracy_score
score=accuracy_score(labels,predictions)
score
# Out:
# 0.8188976377952756
